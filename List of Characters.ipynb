# %%
menu_items=[]
def char_menu():
    i=1
    print 5 * "-", "Characters", 5 * "-"
    for file in os.listdir(char_dir):
        if file.endswith(".json"):
            menu_list=file.split(".")[0]
            print i,".) ",menu_list.title()
            i+=1
            menu_items.insert(i,menu_list)
    print 25 * "-"
    return menu_items

p=char_menu()
menu_len=len(p)

while True:
    s=int(raw_input("Select Character: "))
    if s >=1 and s<=menu_len:
        break
    else:
        print "Invalid Selection! Select a character from the list"

    # Open the character file
file=open(char_dir+"/"+p[s-1]+".json","r")
char_data=file.read()
char_dict=[]
counter=0

for words in char_data.split(":"):
    print counter,"-",words
    char_dict.insert(counter,words)
    counter+=1
# Out:
# ----- Characters -----
# 1 .)  Bang_Sorceror
# 2 .)  Bigboob
# 3 .)  Bigboob_Alchemist
# 4 .)  Crystal
# 5 .)  Detroit
# 6 .)  Hairyballs
# 7 .)  Shoe_Archmage
# -------------------------
# Select Character: 3
# 0 - {"s134"
# 1 -  ["Planetology", "RE/EM", "4", "academic"], "s3"
# 2 -  ["Administration", "RE/PR", "2/5", "academic"], "s270"
# 3 -  ["Seaborne Combat", "AG/AG/IN", "3", "athletic"], "s221"
# 4 -  ["Light Crossbow", "AG/AG/ST", "20", "arms"], "s271"
# 5 -  ["Taunting", "IN", "4", "subterfuge"], "s109"
# 6 -  ["M.A. Sweeps Rank4", "AG/AG/ST", "9", "arms"], "s179"
# 7 -  ["Streetwise", "PR/IN", "2/7", "outdoor"], "s178"
# 8 -  ["Stone Lore", "ME/RE", "1/2", "academic"], "s215"
# 9 -  ["Falchion", "ST/ST/AG", "9", "arms"], "s223"
# 10 -  ["Mace", "ST/ST/AG", "20", "arms"], "s273"
# 11 -  ["Weapon/Armor Maintenance", "AG/SD", "1/2", "general"], "s171"
# 12 -  ["Spell Mastery", "", "2/5", "magical"], "s170"
# 13 -  ["Spell List", "", "1/*", "magical"], "s173"
# 14 -  ["Stalk & Hide", "AG/SD", "6", "subterfuge"], "s172"
# 15 -  ["Sprinting", "QU", "3", "athletic"], "s175"
# 16 -  ["Stilt Walking", "ST/AG", "4", "athletic"], "s174"
# 17 -  ["Star-Gazing", "ME/IN", "2/6", "academic"], "s177"
# 18 -  ["Stone Evaluation", "IN/RE", "1/2", "general"], "s176"
# 19 -  ["Stone Crafts", "SD/AG", "1/2", "general"], "s207"
# 20 -  ["Wood Crafts", "AG/EM", "1/3", "general"], "s197"
# 21 -  ["Trap-Building", "RE/EM", "1/5", "subterfuge"], "s205"
# 22 -  ["Weather-Watching", "IN/EM", "1/4", "academic"], "s204"
# 23 -  ["Warding Lore", "ME/RE", "1/4", "magical"], "s203"
# 24 -  ["Ventriloquism", "SD/IN", "3/6", "linguistic"], "s202"
# 25 -  ["Use/Remove Poison", "AG/IN", "1/4", "deadly"], "s201"
# 26 -  ["Tumbling Evasion", "AG/QU", "3", "arms"], "s196"
# 27 -  ["Transcend Armor", "NA", "4", "magical"], "s248"
# 28 -  ["Blind Fighting
# 29 - Hearing", "RE/EM", "10", "arms"], "qu_pot"
# 30 -  65, "s209"
# 31 -  ["Battle Axe", "ST/ST/AG", "20", "arms"], "s208"
# 32 -  ["Yado", "QU/AG", "6", "arms"], "s57"
# 33 -  ["Drafting", "RE/ME", "1/3", "academic"], "s56"
# 34 -  ["Dowsing", "EM", "2/5", "concentration"], "s55"
# 35 -  ["Diving", "SD/AG", "3", "athletic"], "s54"
# 36 -  ["Divination", "IN/EM", "2/4", "magical"], "s53"
# 37 -  ["Distance Running", "CO", "3", "athletic"], "s52"
# 38 -  ["Disguise", "PR/SD", "3/6", "subterfuge"], "s51"
# 39 -  ["Disarm Trap", "IN/AG", "4", "subterfuge"], "s50"
# 40 -  ["Disarm Foe
# 41 -  Unarmed", "AG", "9", "arms"], "qumb"
# 42 -  0, "s59"
# 43 -  ["Driving", "AG/QU", "3", "outdoor"], "s58"
# 44 -  ["Dragon Lore", "ME/RE", "1/3", "academic"], "s238"
# 45 -  ["Riding - Horse", "EM/AG", "3", "outdoor"], "s233"
# 46 -  ["Spear", "ST/ST/AG", "20", "arms"], "s183"
# 47 -  ["Surgery", "SD/EM/IN", "5", "medical"], "s264"
# 48 -  ["Honing", "AG/EM", "NULL", "general"], "s189"
# 49 -  ["Tale Telling", "PR/ME", "2/6", "linguistic"], "s70"
# 50 -  ["Foraging", "IN/ME", "2/5", "outdoor"], "s200"
# 51 -  ["Tumbling Attack", "AG/ST", "5", "arms"], "s259"
# 52 -  ["Donning/Doffing Armor
# 53 - Chain", "QU/AG", "10", "arms"], "re_stat"
# 54 -  95, "s232"
# 55 -  ["Sling", "AG/AG/ST", "20", "arms"], "s135"
# 56 -  ["Play Instruments
# 57 -  Category 1", "AG/ME", "2/6", "general"], "s230"
# 58 -  ["Short Bow", "AG/AG/ST", "20", "arms"], "s231"
# 59 -  ["Short Sword", "ST/ST/AG", "9", "arms"], "s108"
# 60 -  ["M.A. Sweeps Rank3", "AG/AG/ST", "9", "arms"], "name"
# 61 -  "bigboob", "s234"
# 62 -  ["Two-Handed Sword", "ST/ST/AG", "20", "arms"], "emmb"
# 63 -  0, "s104"
# 64 -  ["M.A. Strikes Rank3", "ST/ST/AG", "9", "arms"], "sd_stat"
# 65 -  65, "s106"
# 66 -  ["M.A. Sweeps Rank1", "AG/AG/ST", "9", "arms"], "s107"
# 67 -  ["M.A. Sweeps Rank2", "AG/AG/ST", "9", "arms"], "em_stat"
# 68 -  97, "s101"
# 69 -  ["Maneuvering in Plate", "AG", "11", "arms"], "s102"
# 70 -  ["M.A. Strikes Rank1", "ST/ST/AG", "9", "arms"], "s103"
# 71 -  ["M.A. Strikes Rank2", "ST/ST/AG", "9", "arms"], "s44"
# 72 -  ["Detect Traps", "IN", "2/5", "perception"], "s45"
# 73 -  ["Diagnostics", "IN/RE", "2", "medical"], "s46"
# 74 -  ["Diplomacy", "PR/IN", "2/5", "social"], "s47"
# 75 -  ["Directed Spells - Bolts", "AG", "2/7", "directed spells"], "s40"
# 76 -  ["Cookery", "RE/AG", "1/2", "general"], "s41"
# 77 -  ["Crafting", "AG/SD", "1/2", "general"], "s42"
# 78 -  ["Dance", "AG/IN", "2/6", "athletic"], "s43"
# 79 -  ["Demon/Devil Lore", "ME/RE", "1/3", "academic"], "s131"
# 80 -  ["Physics", "RE/ME", "2/5", "academic"], "s198"
# 81 -  ["Trickery", "PR/QU", "3", "subterfuge"], "s48"
# 82 -  ["Direction Sense", "IN/RE", "2/4", "perception"], "s49"
# 83 -  ["Disarm Foe
# 84 -  Armed", "AG", "6", "arms"], "s130"
# 85 -  ["Phil./Relig. Doctrine", "ME/RE", "1/2", "academic"], "s239"
# 86 -  ["Play Instruments
# 87 -  Category 2", "AG/ME", "3/7", "general"], "s133"
# 88 -  ["Pick Pockets", "AG/IN", "3", "subterfuge"], "s235"
# 89 -  ["War Hammer", "ST/ST/AG", "20", "arms"], "s105"
# 90 -  ["M.A. Strikes Rank4", "ST/ST/AG", "9", "arms"], "pr_pot"
# 91 -  75, "s100"
# 92 -  ["Maneuvering in Chain", "AG", "10", "arms"], "s137"
# 93 -  ["Poison Lore", "ME/RE", "1/3", "academic"], "s132"
# 94 -  ["Picking Locks", "IN/RE/AG", "4", "subterfuge"], "s250"
# 95 -  ["Blind Fighting
# 96 - Touch", "RE/EM", "25", "arms"], "s184"
# 97 -  ["Surveillance", "IN/SD", "2/6", "perception"], "s229"
# 98 -  ["Scimitar", "ST/ST/AG", "9", "arms"], "s228"
# 99 -  ["Rapier", "ST/ST/AG", "9", "arms"], "s119"
# 100 -  ["Metal Lore", "ME/RE", "1/2", "academic"], "st_pot"
# 101 -  55, "s117"
# 102 -  ["Meditation
# 103 -  Trance", "PR/SD", "1/4", "concentration"], "s116"
# 104 -  ["Meditation
# 105 -  Sleep", "SD/IN", "1/4", "concentration"], "s115"
# 106 -  ["Meditation
# 107 -  Ki", "SD/PR", "3/5", "concentration"], "s114"
# 108 -  ["Meditation
# 109 -  Healing", "SD/EM", "2/4", "concentration"], "s113"
# 110 -  ["Meditation
# 111 -  Death", "SD/PR", "1/5", "concentration"], "s112"
# 112 -  ["Meditation
# 113 -  Cleansing", "SD/EM", "2/4", "concentration"], "s111"
# 114 -  ["Mechanition", "RE/AG", "1/2", "academic"], "s110"
# 115 -  ["Mapping", "RE/ME", "2", "academic"], "s79"
# 116 -  ["Hide Item", "RE/IN", "6", "subterfuge"], "s78"
# 117 -  ["Herding", "EM/PR", "2/6", "outdoor"], "s195"
# 118 -  ["Trading Lore", "ME/RE", "2/6", "academic"], "race"
# 119 -  "Stout Halfling", "s193"
# 120 -  ["Tracking", "IN/RE", "3", "perception"], "s192"
# 121 -  ["Time Sense", "IN/ME", "1/3", "perception"], "s191"
# 122 -  ["Tightrope Walking", "AG/SD", "3", "athletic"], "s190"
# 123 -  ["Targeting Skill", "IN/AG", "2/5", "magical"], "s71"
# 124 -  ["Frenzy", "EM/SD", "6", "concentration"], "st_stat"
# 125 -  25, "s73"
# 126 -  ["General Perception", "IN/IN/RE", "3", "perception"], "s72"
# 127 -  ["Gambling", "ME/PR", "2/6", "social"], "s75"
# 128 -  ["Grappling Hook", "AG", "3", "arms"], "s74"
# 129 -  ["Gimmickry", "IN/RE", "2/4", "general"], "s77"
# 130 -  ["Herb Lore", "ME/RE", "1/3", "academic"], "s76"
# 131 -  ["Heraldry", "ME/RE", "3/5", "academic"], "s275"
# 132 -  ["Weapon Snare", "QU/AG", "6", "arms"], "s19"
# 133 -  ["Architecture", "RE/ME", "2/5", "academic"], "s18"
# 134 -  ["Appraisal", "RE/ME", "1/2", "general"], "s236"
# 135 -  ["War Mattock", "ST/ST/AG", "20", "arms"], "s182"
# 136 -  ["Surfing", "AG/SD", "3", "athletic"], "s206"
# 137 -  ["Weapon Evaluation", "IN/RE", "1/3", "general"], "s13"
# 138 -  ["Ambush", "NA", "9", "deadly"], "s12"
# 139 -  ["Alchemy", "RE/ME", "1/3", "academic"], "s11"
# 140 -  ["Advertising", "IN/RE", "3/5", "general"], "s10"
# 141 -  ["Advanced Math", "RE/ME", "2/5", "academic"], "s17"
# 142 -  ["Anthropology", "IN/EM", "2/5", "academic"], "s16"
# 143 -  ["Animal Training", "EM/PR", "4", "outdoor"], "s15"
# 144 -  ["Animal Healing", "EM/RE", "2/5", "medical"], "s14"
# 145 -  ["Animal Handling", "EM/PR", "2/5", "outdoor"], "s93"
# 146 -  ["Loading", "EM/RE", "3", "outdoor"], "s92"
# 147 -  ["Lip Reading", "IN/RE", "3/5", "linguistic"], "s91"
# 148 -  ["Linguistics", "NA", "1/*", "linguistic"], "s90"
# 149 -  ["Lie Perception", "IN/RE", "3/5", "perception"], "s97"
# 150 -  ["Magical Ritual", "RE/ME", "1/4", "magical"], "s96"
# 151 -  ["Magical Language", "NA", "1/*", "magical"], "s95"
# 152 -  ["Lock Lore", "ME/RE", "1/3", "academic"], "s94"
# 153 -  ["Locate Secret Opening", "IN/RE", "2/5", "perception"], "stmb"
# 154 -  0, "s99"
# 155 -  ["Maneuvering in Rigid Leather", "AG", "9", "arms"], "comb"
# 156 -  0, "s258"
# 157 -  ["Donning/Doffing Armor
# 158 - RL", "QU/AG", "9", "arms"], "in_stat"
# 159 -  80, "s128"
# 160 -  ["Navigation", "RE/IN", "2/6", "academic"], "s129"
# 161 -  ["Painting", "IN/AG", "2/5", "general"], "s281"
# 162 -  ["TWC - Scimitar
# 163 -  RH", "ST/ST/AG", "9", "arms"], "s185"
# 164 -  ["Swimming", "AG", "3", "athletic"], "sdmb"
# 165 -  0, "re_pot"
# 166 -  95, "s120"
# 167 -  ["Midwifery", "EM/ME/IN", "4", "medical"], "s121"
# 168 -  ["Military Organization", "PR/RE", "3/6", "academic"], "s126"
# 169 -  ["Mnemonics", "ME/SD", "1/4", "concentration"], "s127"
# 170 -  ["Music", "AG/EM", "2/6", "linguistic"], "ag_stat"
# 171 -  75, "s125"
# 172 -  ["Missile Artillery", "IN/AG", "3/6", "arms"], "s222"
# 173 -  ["Long Bow", "AG/AG/ST", "20", "arms"], "s68"
# 174 -  ["Flora Lore", "ME/RE", "1/4", "academic"], "s69"
# 175 -  ["Fying/Gliding", "ME/RE", "3", "athletic"], "qu_stat"
# 176 -  65, "s67"
# 177 -  ["Fletching", "AG/SD", "1/3", "general"], "s64"
# 178 -  ["Falsification", "SD/RE", "1/3", "subterfuge"], "s65"
# 179 -  ["Fauna Lore", "ME/RE", "1/4", "academic"], "s62"
# 180 -  ["Engineering", "RE/ME", "1/2", "academic"], "s63"
# 181 -  ["Faerie Lore", "ME/RE", "1/3", "academic"], "s60"
# 182 -  ["Drug Tolerance", "CO/SD", "2/5", "medical"], "s61"
# 183 -  ["Duping", "PR", "3/5", "social"], "s194"
# 184 -  ["Trading", "RE/EM", "3/5", "linguistic"], "s186"
# 185 -  ["Symbol Lore", "ME/RE", "1/4", "magical"], "prmb"
# 186 -  0, "s225"
# 187 -  ["Morning Star", "ST/ST/AG", "20", "arms"], "me_stat"
# 188 -  85, "s256"
# 189 -  ["Distract Foe", "AG/QU", "9", "arms"], "s80"
# 190 -  ["Horticulture", "RE/EM", "1/4", "general"], "s81"
# 191 -  ["Hostile Environments", "AG/SD", "3", "outdoor"], "s82"
# 192 -  ["Hypnosis", "PR/SD", "3", "medical"], "s83"
# 193 -  ["Iai", "QU/AG", "15", "arms"], "s84"
# 194 -  ["Interrogation", "RE/AG", "4", "social"], "s85"
# 195 -  ["Juggling", "AG/IN", "3", "athletic"], "s86"
# 196 -  ["Jumping", "ST/AG", "4", "athletic"], "s87"
# 197 -  ["Lancing", "ST/AG", "18", "arms"], "s88"
# 198 -  ["Leadership", "PR/RE", "2/4", "social"], "s89"
# 199 -  ["Leather Working", "AG/RE", "3", "general"], "s244"
# 200 -  ["Adrenal Spell Avoidance", "PR", "6", "concentration"], "s139"
# 201 -  ["Pole Vaulting", "ST/AG", "5", "athletic"], "s138"
# 202 -  ["Poison Perception", "IN/RE", "1/4", "perception"], "agmb"
# 203 -  0, "s249"
# 204 -  ["Blind Fighting
# 205 - Smell", "RE/ME", "20", "arms"], "s98"
# 206 -  ["Maneuvering in Soft Leather", "AG", "9", "arms"], "s243"
# 207 -  ["Directed Spells - Adrenal Focus", "AG", "2/7", "directed spells"], "s242"
# 208 -  ["Shield Bash", "ST/ST/AG", "20", "arms"], "s241"
# 209 -  ["Adrenal Defense", "NA", "20", "concentration"], "s240"
# 210 -  ["Play Instruments
# 211 -  Category 3", "AG/ME", "3", "general"], "s136"
# 212 -  ["Poetic Improvisation", "IN/RE", "2/6", "linguistic"], "s246"
# 213 -  ["Awakening", "IN", "18", "arms"], "ag_pot"
# 214 -  75, "in_pot"
# 215 -  80, "s247"
# 216 -  ["Battle Perception", "IN/ME", "2/4", "academic"], "s166"
# 217 -  ["Skiing", "AG/SD", "3", "athletic"], "s180"
# 218 -  ["Stunned Maneuvering", "SD", "4", "arms"], "s279"
# 219 -  ["Whip Grapple
# 220 -  3", "AG/ST", "9", "arms"], "s251"
# 221 -  ["Blind Fighting
# 222 - Intuition", "IN", "25", "arms"], "s39"
# 223 -  ["Control Lycanthropy", "SD", "3/6", "concentration"], "s38"
# 224 -  ["Contortions", "AG/SD", "5", "athletic"], "memb"
# 225 -  0, "s35"
# 226 -  ["Channeling", "IN", "7", "magical"], "s34"
# 227 -  ["Caving", "SD/RE", "3", "outdoor"], "s37"
# 228 -  ["Climbing", "AG", "7", "athletic"], "s36"
# 229 -  ["Circle Lore", "ME/RE", "2/4", "magical"], "s31"
# 230 -  ["Brawling", "RE/IN", "18", "arms"], "s30"
# 231 -  ["Body Development", "CO", "6", "body development"], "s33"
# 232 -  ["Camouflage", "RE/IN", "6", "subterfuge"], "s32"
# 233 -  ["Bribery", "PR/RE", "2/6", "subterfuge"], "inmb"
# 234 -  0, "s141"
# 235 -  ["Power Projection", "NA", "2/4", "magical"], "s142"
# 236 -  ["Propaganda", "IN/EM", "3/5", "linguistic"], "s143"
# 237 -  ["Public Speaking", "EM/PR", "2/6", "linguistic"], "s144"
# 238 -  ["Racial History", "ME/RE", "1/4", "academic"], "s145"
# 239 -  ["Rappling", "AG", "7", "athletic"], "s146"
# 240 -  ["Read Tracks", "IN/RE", "3/7", "perception"], "s147"
# 241 -  ["Region Lore", "RE/ME", "2/5", "outdoor"], "s148"
# 242 -  ["Reverse Stroke", "AG/RE", "20", "arms"], "s149"
# 243 -  ["Rope Mastery", "ME/AG", "3", "general"], "s237"
# 244 -  ["Whip", "ST/ST/AG", "20", "arms"], "s278"
# 245 -  ["Whip Grapple
# 246 -  2", "AG/ST", "9", "arms"], "s181"
# 247 -  ["Subduing", "AG/QU", "6", "arms"], "s261"
# 248 -  ["Feinting", "QU/PR", "6", "arms"], "s260"
# 249 -  ["Donning/Doffing Armor
# 250 - Plate", "QU/AG", "11", "arms"], "s282"
# 251 -  ["TWC - Scimitar
# 252 -  LH", "ST/ST/AG", "9", "arms"], "s262"
# 253 -  ["Focus", "SD", "18", "arms"], "s263"
# 254 -  ["Holding Breath", "CO/SD", "6", "body development"], "s122"
# 255 -  ["Mimicry", "IN/SD", "2/6", "linguistic"], "s245"
# 256 -  ["Airborne Combat", "AG/QU", "18", "arms"], "s266"
# 257 -  ["Intimidation", "PR/RE", "2/5", "social"], "s123"
# 258 -  ["Mimery", "AG/SD", "3/6", "subterfuge"], "lvl"
# 259 -  0, "remb"
# 260 -  0, "s252"
# 261 -  ["Cryptography", "IN/RE", "2/6", "linguistic"], "s156"
# 262 -  ["Second Aid", "SD/EM/IN", "3/6", "medical"], "s276"
# 263 -  ["Weapon Trickery", "AG/QU", "9", "arms"], "s253"
# 264 -  ["Defensive Weaving", "NA", "20", "concentration"], "pro_name"
# 265 -  "Alchemist", "s254"
# 266 -  ["Dentistry", "ME/AG", "5", "medical"], "s265"
# 267 -  ["Hygiene", "CO/SD", "3", "body development"], "s154"
# 268 -  ["Sculpting", "IN/AG", "1/4", "general"], "co_pot"
# 269 -  65, "s188"
# 270 -  ["Tactics", "IN/RE", "2/4", "academic"], "s153"
# 271 -  ["Sanity Healing Lore", "ME/EM", "2", "academic"], "s152"
# 272 -  ["Sailing", "AG/IN", "3", "athletic"], "s151"
# 273 -  ["Runes", "EM/IN", "1/3", "magical"], "s150"
# 274 -  ["Rowing", "ST/SD", "3", "athletic"], "s157"
# 275 -  ["Seduction", "EM/PR", "2/5", "social"], "s124"
# 276 -  ["Mining", "RE/IN", "3", "academic"], "s155"
# 277 -  ["Scrounge", "IN/RE", "2/5", "outdoor"], "sd_pot"
# 278 -  65, "s269"
# 279 -  ["Prepared Shot", "SD/IN", "6", "concentration"], "s268"
# 280 -  ["Moving Strike", "AG/SD", "20", "arms"], "s159"
# 281 -  ["Sense Ambush/Assassin", "IN/RE", "3", "perception"], "s158"
# 282 -  ["Siege Engineer", "RE/IN", "2/4", "academic"], "s187"
# 283 -  ["Tactical Games", "RE/ME", "1/4", "general"], "s277"
# 284 -  ["Whip Grapple
# 285 -  1", "AG/ST", "9", "arms"], "s9"
# 286 -  ["Adrenal Move
# 287 -  Strength", "PR/SD", "6", "concentration"], "s8"
# 288 -  ["Adrenal Move
# 289 -  Speed", "PR/SD", "6", "concentration"], "realm"
# 290 -  "EM", "s283"
# 291 -  ["Dagger", "ST", "Thrown", "AG/AG/ST"], "em_pot"
# 292 -  97, "s2"
# 293 -  ["Acting", "PR/EM", "3/6", "subterfuge"], "s1"
# 294 -  ["Acrobatics", "AG/QU", "3", "athletic"], "s7"
# 295 -  ["Adrenal Move
# 296 -  Quick Draw", "PR/SD", "4", "concentration"], "s6"
# 297 -  ["Adrenal Move
# 298 -  Leaping", "PR/SD", "6", "concentration"], "s5"
# 299 -  ["Adrenal Move
# 300 -  Landing", "PR/SD", "6", "concentration"], "s4"
# 301 -  ["Adrenal Move
# 302 -  Balance", "PR/SD", "6", "concentration"], "s220"
# 303 -  ["Lance", "ST/ST/AG", "NULL", "arms"], "s224"
# 304 -  ["Main Gauche", "ST/ST/AG", "9", "arms"], "s274"
# 305 -  ["Weapon Brawling", "AG/QU/ST", "NULL", "arms"], "s255"
# 306 -  ["Directed Strength", "SD", "6", "arms"], "s267"
# 307 -  ["Mind Block", "SD/PR", "11", "general"], "me_pot"
# 308 -  85, "pr_stat"
# 309 -  75, "s66"
# 310 -  ["First Aid", "SD/EM", "2/5", "medical"], "s226"
# 311 -  ["Polearm", "ST/ST/AG", "20", "arms"], "s168"
# 312 -  ["Smithing", "ST/AG", "1/2", "general"], "s169"
# 313 -  ["Spacial Locate Awareness", "IN", "3/6", "concentration"], "co_stat"
# 314 -  65, "s167"
# 315 -  ["Skinning", "AG/IN", "3", "general"], "s164"
# 316 -  ["Silent Kill", "AG/IN", "6", "deadly"], "s165"
# 317 -  ["Skating", "AG/SD", "3", "athletic"], "s162"
# 318 -  ["Signaling", "ME/SD", "1/5", "linguistic"], "s163"
# 319 -  ["Singing", "PR/IN", "2/6", "linguistic"], "s160"
# 320 -  ["Sense Reality Warp", "IN/EM", "1/4", "perception"], "s161"
# 321 -  ["Set Traps", "RE/AG", "4", "subterfuge"], "s214"
# 322 -  ["Dagger", "ST/ST/AG", "9", "arms"], "s140"
# 323 -  ["Power Perception", "IN/RE", "1/3", "magical"], "s216"
# 324 -  ["Flail", "ST/ST/AG", "20", "arms"], "s217"
# 325 -  ["Hand Axe", "ST/ST/AG", "9", "arms"], "s210"
# 326 -  ["Bola", "AG/AG/ST", "20", "arms"], "s211"
# 327 -  ["Broadsword", "ST/ST/AG", "9", "arms"], "s212"
# 328 -  ["Club", "ST/ST/AG", "20", "arms"], "s213"
# 329 -  ["Composite Bow", "AG/AG/ST", "20", "arms"], "s118"
# 330 -  ["Metal Evaluation", "IN/RE", "1/2", "general"], "s218"
# 331 -  ["Heavy Crossbow", "AG/AG/ST", "20", "arms"], "s219"
# 332 -  ["Javelin", "ST/ST/AG", "20", "arms"], "s22"
# 333 -  ["Athletic Games", "ST/AG/QU", "7", "athletic"], "s23"
# 334 -  ["Attunement", "EM/IN", "1/3", "magical"], "s20"
# 335 -  ["Armor Evaluation", "IN/RE", "1/3", "general"], "s21"
# 336 -  ["Astronomy", "ME/RE", "3/7", "academic"], "s26"
# 337 -  ["Begging", "PR/EM", "2/6", "subterfuge"], "s27"
# 338 -  ["Biochemistry", "IN/RE", "5", "academic"], "s24"
# 339 -  ["Basic Math", "RE/ME", "1/4", "academic"], "s25"
# 340 -  ["Beast Mastery", "EM/PR", "5", "outdoor"], "s280"
# 341 -  ["Whip Grapple
# 342 -  4", "AG/ST", "9", "arms"], "s272"
# 343 -  ["Unhorsing", "ST/ST/AG", "18", "arms"], "s28"
# 344 -  ["Boat Pilot", "ME/AG", "2/6", "academic"], "s29"
# 345 -  ["Body Damage Stablize", "SD/EM", "3/5", "concentration"], "s257"
# 346 -  ["Donning/Doffing Armor
# 347 - SL", "QU/AG", "9", "arms"], "s227"
# 348 -  ["Quarterstaff", "ST/ST/AG", "20", "arms"], "s199"
# 349 -  ["Tumbling", "AG/SD", "3", "athletic"]}

# %%
user_name="rose"
tarch=[]
for file in os.listdir(char_dir):
    if file.startswith(user_name) == True:
        print file
        tarch.append(file)
    print tarch

    print 'creating archive'
    #zf = zipfile.ZipFile('zipfile_write.zip', mode='w')
    #try:
        #print 'adding README.txt'
        #zf.write(tarch)
    #finally:
        #print 'closing'
        #zf.close()

    #print
# Out:
# []
# creating archive
# []
# creating archive
# []
# creating archive
# []
# creating archive
# []
# creating archive
# []
# creating archive
# []
# creating archive
