# %%
lst=[]
words=[]
file=open("cfg/ds.csv","r")
lst=file.read()
cnt=1
#print lst
for x in lst.splitlines():
    for y in x.split(','):
        if words[cnt].is
        words.insert=(cnt,y)
        cnt+=1
    pass
print words
# Out:
# {1: '1', 2: 'Acrobatics', 3: 'AG', 4: 'QU', 5: '', 6: 'AG/QU', 7: 'athletic', 8: 'NULL', 9: '3', 10: '2/7', 11: '2/5', 12: '1/3', 13: '1/2', 14: '2/5', 15: '2/5', 16: '1/4', 17: '5', 18: '1/3', 19: '2/6', 20: '1/3', 21: '2/6', 22: '2/5', 23: '3', 24: '1/4', 25: '1/5', 26: '1/3', 27: '2/6', 28: '2/6', 29: '2/7', 30: '3', 31: '3', 32: '3', 33: '3', 34: '3', 35: '3', 36: '2/7', 37: '2/7', 38: '2/7', 39: '2/7', 40: '3/7', 41: '5', 42: '3/7', 43: '3/7', 44: '3', 45: '3/7', 46: '3', 47: '3', 48: '3', 49: '4', 50: '1/4', 51: '2/5', 52: 'NULL', 53: 'NULL', 54: 'NULL', 55: 'NULL', 56: 'NULL', 57: '2', 58: 'Acting', 59: 'PR', 60: 'EM', 61: '', 62: 'PR/EM', 63: 'subterfuge', 64: 'NULL', 65: '3/6', 66: '2/7', 67: '2/6', 68: '2/5', 69: '2/5', 70: '2/6', 71: '2/5', 72: '1/3', 73: '2/5', 74: '2/5', 75: '1/3', 76: '2/5', 77: '1/5', 78: '2/6', 79: '3/6', 80: '2/6', 81: '2/6', 82: '2/5', 83: '3/6', 84: '2/6', 85: '3/6', 86: '3/6', 87: '2/7', 88: '3/6', 89: '3/6', 90: '3/5', 91: '1/3', 92: '2/7', 93: '
# ...
