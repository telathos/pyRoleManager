# %%
file=open("base.txt","w")
d={}
d['name']="shen"
d['lvl']=0
d['pro']="Monk"
print d
file.writelines(d)
file.close()

f2=open("base.txt","r")
f2.read()
# Out:
# {'lvl': 0, 'pro': 'Monk', 'name': 'shen'}
# 'lvlproname'

# %%
import json

# as requested in comment
d={}
d['name']="shen"
d['lvl']=0
d['pro']="Monk"

with open('file.txt', 'w') as file:
     file.write(json.dumps(d))

# %%
file=open('cfg/ds_old.csv','r')
i=0
for x in file:
    for y in x.split(","):
        print y,"-",i
        i+=1
# Out:
# id - 0
# skillname - 1
# stat1 - 2
# stat2 - 3
# stat3 - 4
# stats - 5
# category - 6
# wea - 7
# Alchemist - 8
# Animist - 9
# Barbarian - 10
# Burglar - 11
# Dancer - 12
# Fighter - 13
# "High Warrior Monk" - 14
# Rogue - 15
# Scholar - 16
# Thief - 17
# Trader - 18
# "Warrior Monk" - 19
# Bard - 20
# Beastmaster - 21
# Delver - 22
# Dervish - 23
# Monk - 24
# Nightblade - 25
# Paladin - 26
# Ranger - 27
# "Warrior Mage" - 28
# Archmage - 29
# Sorcerer - 30
# Magician - 31
# Runemaster - 32
# Conjuror - 33
# Illusionist - 34
# Cleric - 35
# Druid - 36
# Healer - 37
# Shaman - 38
# "Lay Healer" - 39
# Sage - 40
# Mentalist - 41
# Seer - 42
# Astrologer - 43
# "Crystal Mage" - 44
# Mystic - 45
# Necromancer - 46
# Warlock - 47
# Witch
# - 48
# 1 - 49
# Acrobatics - 50
# AG - 51
# QU - 52
#  - 53
# AG/QU - 54
# athletic - 55
# NULL - 56
# 3 - 57
# 2/7 - 58
# 2/5 - 59
# 1/3 - 60
# 1/2 - 61
# 2/5 - 62
# 2/5 - 63
# 1/4 - 64
# 5 - 65
# 1/3 - 66
# 2/6 - 67
# 1/3 - 68
# 2/6 - 69
# 2/5 - 70
# ...
