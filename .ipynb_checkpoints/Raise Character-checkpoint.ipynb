# %%
import json
import re

char_dir="char"
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# Open the file
with open(char_dir+"/crystal.json","r") as cf:
    char_dict = json.load(cf)
#print "Name: ",char_dict['name']
#print char_dict['s227']
#print char_dict['s228']
#print 25 * "-"

sslist=[]
pattern=re.compile("^s[0-9]+")
for x in char_dict.keys():
    if pattern.match(x):
        #print "Match: ",x
        sslist.append(x)
    else:
        pass

sslist.sort(key=natural_keys)
skcnt=1
sortcnt=1
print "| 1.) A      10.) J      19.) S"
print "| 2.) B      11.) K      20.) T"
print "| 3.) C      12.) L      21.) U"
print "| 4.) D      13.) M      22.) V"
print "| 5.) E      14.) N      23.) W"
print "| 6.) F      15.) O      24.) X"
print "| 7.) G      16.) P      25.) Y"
print "| 8.) H      17.) Q      26.) Z"
print "| 9.) I      18.) R"
print
ska=int(raw_input('Select First Letter of Skill: '))
#print ska
wordcnt=0
for words in sslist:
    if char_dict[words][0].startswith('A'):
        wordcnt+=1
    if char_dict[words][0].startswith('B'):
        wordcnt+=1
        bt=wordcnt
        print bt,":bt"
    if char_dict[words][0].startswith('C'):
        wordcnt+=1
        ct=wordcnt
    if char_dict[words][0].startswith('D'):
        wordcnt+=1
        dt=wordcnt
    if char_dict[words][0].startswith('E'):
        wordcnt+=1
        et=wordcnt
    if char_dict[words][0].startswith('F'):
        wordcnt+=1
    if char_dict[words][0].startswith('G'):
        wordcnt+=1
    if char_dict[words][0].startswith('H'):
        wordcnt+=1
    if char_dict[words][0].startswith('I'):
        wordcnt+=1
    if char_dict[words][0].startswith('J'):
        wordcnt+=1
    if char_dict[words][0].startswith('K'):
        wordcnt+=1
    if char_dict[words][0].startswith('L'):
        wordcnt+=1
    if char_dict[words][0].startswith('M'):
        wordcnt+=1
    if char_dict[words][0].startswith('N'):
        wordcnt+=1
    if char_dict[words][0].startswith('O'):
        wordcnt+=1
    if char_dict[words][0].startswith('P'):
        wordcnt+=1
    if char_dict[words][0].startswith('Q'):
        wordcnt+=1
    if char_dict[words][0].startswith('R'):
        wordcnt+=1
    if char_dict[words][0].startswith('S'):
        wordcnt+=1
    if char_dict[words][0].startswith('T'):
        wordcnt+=1
    if char_dict[words][0].startswith('U'):
        wordcnt+=1
    if char_dict[words][0].startswith('V'):
        wordcnt+=1
    if char_dict[words][0].startswith('W'):
        wordcnt+=1
    if char_dict[words][0].startswith('X'):
        wordcnt+=1
    if char_dict[words][0].startswith('Y'):
        wordcnt+=1
    if char_dict[words][0].startswith('Z'):
        wordcnt+=1
#print wordcnt,":wc"

adict=[]
bdict=[]
cdict=[]
for key in sslist:
    if ska == 1 and char_dict[key][0].startswith('A'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
        adict[sortcnt]=char_dict[key]
        print adict
    if ska == 2 and char_dict[key][0].startswith('B'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 3 and char_dict[key][0].startswith('C'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 4 and char_dict[key][0].startswith('D'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 5 and char_dict[key][0].startswith('E'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 6 and char_dict[key][0].startswith('F'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 7 and char_dict[key][0].startswith('G'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 8 and char_dict[key][0].startswith('H'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 9 and char_dict[key][0].startswith('I'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 10 and char_dict[key][0].startswith('J'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 11 and char_dict[key][0].startswith('K'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 12 and char_dict[key][0].startswith('L'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 13 and char_dict[key][0].startswith('M'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 14 and char_dict[key][0].startswith('N'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 15 and char_dict[key][0].startswith('O'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 16 and char_dict[key][0].startswith('P'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 17 and char_dict[key][0].startswith('Q'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 18 and char_dict[key][0].startswith('R'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 19 and char_dict[key][0].startswith('S'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 20 and char_dict[key][0].startswith('T'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 21 and char_dict[key][0].startswith('U'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 22 and char_dict[key][0].startswith('V'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 23 and char_dict[key][0].startswith('W'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 24 and char_dict[key][0].startswith('X'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 25 and char_dict[key][0].startswith('Y'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
    if ska == 26 and char_dict[key][0].startswith('Z'):
        print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        sortcnt+=1
        alen=(sortcnt-1)
#print alen
skloop=True
while skloop:
    sk=int(raw_input("Select a skill: "))
    #print char_dict[key][0]
    if sk>alen or sk<1:
        print "Please select a skill within the range:"
    else:
        skloop=False
    if ska==2:
        skt=int(ska)+int(bt)
        sks="s"+`skt`
    else:
        sks="s"+`sk`
    #sks="s"+`sk`
    print sks
    #if char_dict[key][0].startswith('A'):
        #print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0])
        #sortcnt+=1
        #sk=int(raw_input("Select a skill: "))
    #print "| {:>3}.) {:35}|{:^10}|{:^5}|{:2}|{:2}|{:2}|".format(skcnt,char_dict[key][0],char_dict[key][1],char_dict[key][2],char_dict[key][4],char_dict[key][5],char_dict[key][6],char_dict[key][7])
    #skcnt+=1
#print 70 * "-"
#print
#sk=int(raw_input("Select a skill: "))
#print sk
#print "| {:>2}.) {:35}".format(sortcnt,char_dict[key][0].startswith('A'))
# Out:
# | 1.) A      10.) J      19.) S
# | 2.) B      11.) K      20.) T
# | 3.) C      12.) L      21.) U
# | 4.) D      13.) M      22.) V
# | 5.) E      14.) N      23.) W
# | 6.) F      15.) O      24.) X
# | 7.) G      16.) P      25.) Y
# | 8.) H      17.) Q      26.) Z
# | 9.) I      18.) R
#
# Select First Letter of Skill: 1
# 24 :bt
# 25 :bt
# 26 :bt
# 27 :bt
# 28 :bt
# 29 :bt
# 30 :bt
# 31 :bt
# 32 :bt
# 209 :bt
# 210 :bt
# 211 :bt
# 247 :bt
# 248 :bt
# 249 :bt
# 250 :bt
# 251 :bt
# |  1.) Acrobatics
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-462cceed013a> in <module>()
#     115         sortcnt+=1
#     116         alen=(sortcnt-1)
# --> 117         adict[sortcnt]=char_dict[key]
#     118         print adict
#     119     if ska == 2 and char_dict[key][0].startswith('B'):
#
# IndexError: list assignment index out of range

# %%
cfg_dir="cfg"
with open(cfg_dir+"/ds.csv") as f:
    sl=f.read().splitlines()
    f.close()
skill_list=[]

for list in sl:
    skill_list.append(list.split(","))
crt=1
for outer_list in skill_list:
    s='s'+`crt`
    index=51
    print outer_list[1],":skill"
    print outer_list[5],":skill stats"
    print outer_list[6],":cat"
    print outer_list[12],":skill cost"
# Out:
# skillname :skill
# stats :skill stats
# category :cat
# Dancer :skill cost
# Acrobatics :skill
# AG/QU :skill stats
# athletic :cat
# 1/2 :skill cost
# Acting :skill
# PR/EM :skill stats
# subterfuge :cat
# 2/5 :skill cost
# Administration :skill
# RE/PR :skill stats
# academic :cat
# 2/5 :skill cost
# "Adrenal Defense" :skill
# NA :skill stats
# concentration :cat
# 3/8 :skill cost
# "Adrenal Move: Balance" :skill
# PR/SD :skill stats
# concentration :cat
# 1/2 :skill cost
# "Adrenal Move: Landing" :skill
# PR/SD :skill stats
# concentration :cat
# 1/2 :skill cost
# "Adrenal Move: Leaping" :skill
# PR/SD :skill stats
# concentration :cat
# 1/3 :skill cost
# "Adrenal Move: Quick Draw" :skill
# PR/SD :skill stats
# concentration :cat
# 1/2 :skill cost
# "Adrenal Move: Speed" :skill
# PR/SD :skill stats
# concentration :cat
# 1/3 :skill cost
# "Adrenal Move: Strength" :skill
# PR/SD :skill stats
# concentration :cat
# 1/5 :skill cost
# "Adrenal Spell Avoidance" :skill
# ...

# %%
import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split('(\d+)', text) ]

alist=[
    "something1",
    "something12",
    "something17",
    "something2",
    "something25",
    "something29"]

alist.sort(key=natural_keys)
print(alist)
# Out:
# ['something1', 'something2', 'something12', 'something17', 'something25', 'something29']
