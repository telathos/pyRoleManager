# %%
import os
char_dir="char"


    
def skill_lookup(stat):
    skill_bonus=999
    dp=99.0
    pp=10.0
    print "stat:",stat
    if stat==1:
        skill_bonus=-25
        dp=1.0
        pp=0.0
    elif stat==2:
        skill_bonus=-24
        dp=1.3
        pp=0.0
    elif stat==3:
        skill_bonus=-21
        dp=1.6
        pp=0.0
    elif stat==4:
        skill_bonus=-19
        dp=1.8
        pp=0.0
    elif stat==5:
        skill_bonus=-17
        dp=2.0
        pp=0.0
    elif stat==6:
        skill_bonus=-15
        dp=2.2
        pp=0.0
    elif stat==7:
        skill_bonus=-14
        dp=2.4
        pp=0.0
    elif stat==8:
        skill_bonus=-13
        dp=2.6
        pp=0.0
    elif stat==9:
        skill_bonus=-12
        dp=2.7
        pp=0.0
    elif stat==10:
        skill_bonus=-11
        dp=2.8
        pp=0.0
    elif stat==11:
        skill_bonus=-10
        dp=2.9
        pp=0.0
    elif 12<=stat<=15:
        skill_bonus=-9
        dp=3.0
        pp=0.0
    elif 16<=stat<=18:
        skill_bonus=-8
        dp=3.3
        pp=0.0
    elif 19<=stat<=21:
        skill_bonus=-7
        dp=3.6
        pp=0.0
    elif 22<=stat<=24:
        skill_bonus=-6
        dp=3.8
        pp=0.0
    elif 25<=stat<=27:
        skill_bonus=-5
        dp=4.0
        pp=0.0
    elif 28<=stat<=30:
        skill_bonus=-4
        dp=4.3
        pp=0.0
    elif 31<=stat<=32:
        skill_bonus=-3
        dp=4.6
        pp=0.0
    elif 33<=stat<=36:
        skill_bonus=-2
        dp=4.8
        pp=0.0
    elif 37<=stat<=40:
        skill_bonus=-1
        dp=5.0
        pp=0.0
    elif 41<=stat<=59:
        skill_bonus=0
        dp=5.5
        pp=0.0
    elif 60<=stat<=63:
        skill_bonus=1
        dp=6.0
        pp=0.2
    elif 64<=stat<=67:
        skill_bonus=2
        dp=6.3
        pp=0.4
    elif 68<=stat<=71:
        skill_bonus=3
        dp=6.6
        pp=0.6
    elif 72<=stat<=74:
        skill_bonus=4
        dp=6.8
        pp=0.8
    elif 75<=stat<=77:
        skill_bonus=5
        dp=7.0
        pp=1.0
    elif 78<=stat<=80:
        skill_bonus=6
        dp=7.4
        pp=1.1
        print "skill Bonus:",skill_bonus
        print "num:",78
    elif 81<=stat<=83:
        skill_bonus=7
        dp=7.7
        pp=1.2
    elif 84<=stat<=86:
        skill_bonus=8
        dp=8.0
        pp=1.3
    elif 87<=stat<=89:
        skill_bonus=9
        dp=8.2
        pp=1.4
    elif stat==90:
        skill_bonus=10
        dp=8.4
        pp=1.5
    elif stat==91:
        skill_bonus=11
        dp=8.6
        pp=1.6
    elif stat==92:
        skill_bonus=12
        dp=8.7
        pp=1.7
    elif stat==93:
        skill_bonus=13
        dp=8.8
        pp=1.8
    elif stat==94:
        skill_bonus=14
        dp=8.9
        pp=1.9
    elif stat==95:
        skill_bonus=15
        dp=9.0
        pp=2.0
    elif stat==96:
        skill_bonus=17
        dp=9.2
        pp=2.2
    elif stat==97:
        skill_bonus=19
        dp=9.4
        pp=2.4
    elif stat==98:
        skill_bonus=21
        dp=9.6
        pp=2.6
    elif stat==99:
        skill_bonus=23
        dp=9.8
        pp=2.8
    elif stat==100:
        skill_bonus=25
        dp=10.0
        pp=3.0
    elif stat==101:
        skill_bonus=30

    #skill_bonus = (stat-50)/2
    
    return (skill_bonus,dp,pp)


def show_char(name,pro_name,race,st_cur,qu_cur,pr_cur,in_cur,em_cur,co_cur,ag_cur,sd_cur,me_cur,re_cur,
              st_pot,qu_pot,pr_pot,in_pot,em_pot,co_pot,ag_pot,sd_pot,me_pot,re_pot):
#def show_char():
    print st_cur
    stb=skill_lookup(st_cur)
    
    print pro_name
    print stb
    print race
    print ""
    print 82 * "-"
    print "| Name: %s" % name.title()
    print "| Profession: %s" % pro_name.title()
    print "| Race: %s" % race.title()
    print 82 * "-"
    print "|                                   Stats                                        |"
    print 82 * "-"
    print "|                      |         |           |  Stat |  Race | Dev | PP  | Total |"
    print "|                      | Current |   Pot'l   | Bonus | Bonus | Pts | Pts | Bonus |"
    print 82 * "-"
    print "| Strength (ST)        |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(st_cur,st_pot,stb[0],5,stb[1],stb[2],45)
    print "| Quickness (QU)       |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(qu_cur,qu_pot,4,5,2,0,45)
    print "| Presence (PR)        |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(pr_cur,pr_pot,4,5,2,0,45)
    print "| Intuition (IN)       |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(in_cur,in_pot,4,5,2,0,45)
    print "| Empathy (EM)         |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(em_cur,em_pot,4,5,2,0,45)
    print "| Constitution (CO)    |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(co_cur,co_pot,4,5,2,0,45)
    print "| Agility (AG)         |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(ag_cur,ag_pot,4,5,2,0,45)
    print "| Self Discipline (SD) |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(sd_cur,sd_pot,4,5,2,0,45)
    print "| Memory (ME)          |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(me_cur,me_pot,4,5,2,0,45)
    print "| Reasoning (RE)       |{:^9}|{:^11}|{:^7}|{:^7}|{:^5}|{:^5}|{:^7}|".format(re_cur,re_pot,4,5,2,0,45)
    print 82 * "-"
    
    
# Create a menu of characters
menu_items = []
def char_menu():
    i=1
    print 5 * "-", "Characters", 5 * "-"
    for file in os.listdir(char_dir):
        if file.endswith(".txt"):
            menu_list=file.split(".")[0]
            print i,".) ",menu_list.title()
            i+=1
            menu_items.insert(i,menu_list)
    print 25 * "-"
    return menu_items

p=char_menu()
menu_len=len(p)

while True:
    s=int(raw_input("Select Character: "))
    if s >=1 and s<=menu_len:
        break
    else:
        print "Invalid Selection! Select a character from the list"
    
# Open the file
file=open(char_dir+"/"+p[s-1]+".txt","r")
char_data=file.read()
char_dict=[]
counter=0

for words in char_data.split(":"):
    #print counter,"-",words
    char_dict.insert(counter,words)
    counter+=1

show_char(char_dict[0],char_dict[1],char_dict[2],char_dict[3],char_dict[4],char_dict[5],char_dict[6],char_dict[7],
         char_dict[8],char_dict[9],char_dict[10],char_dict[11],char_dict[12],char_dict[13],char_dict[14],char_dict[15],
         char_dict[16],char_dict[17],char_dict[18],char_dict[19],char_dict[20],char_dict[21],char_dict[22])
# Out:
# ----- Characters -----
# 1 .)  Burke
# 2 .)  New
# 3 .)  Rose
# 4 .)  Coder
# 5 .)  Swisher
# 6 .)  Awyen
# -------------------------
# Select Character: 6
# 78
# stat: 78
# Mystic
# (999, 99.0, 10.0)
# Wood Elf
#
# ----------------------------------------------------------------------------------
# | Name: Awyen
# | Profession: Mystic
# | Race: Wood Elf
# ----------------------------------------------------------------------------------
# |                                   Stats                                        |
# ----------------------------------------------------------------------------------
# |                      |         |           |  Stat |  Race | Dev | PP  | Total |
# |                      | Current |   Pot'l   | Bonus | Bonus | Pts | Pts | Bonus |
# ----------------------------------------------------------------------------------
# | Strength (ST)        |   78    |    91     |  999  |   5   |99.0 |10.0 |  45   |
# ...

# %%
p=skill_lookup(78)
print p
print p[0]
print p[2]
# Out:
# (6, 7.4, 1.1)
# 6
# 1.1

# %%
def skill_lookup(stat):
    global skill_bonus
    global dp
    global pp
    print "stat:",stat
    if stat==1:
        skill_bonus=-25
        dp=1.0
        pp=0.0
    elif stat==2:
        skill_bonus=-24
        dp=1.3
        pp=0.0
    elif stat==3:
        skill_bonus=-21
        dp=1.6
        pp=0.0
    elif stat==4:
        skill_bonus=-19
        dp=1.8
        pp=0.0
    elif stat==5:
        skill_bonus=17
        dp=2.0
        pp=0.0
    elif stat==6:
        skill_bonus=-15
        dp=2.2
        pp=0.0
    elif stat==7:
        skill_bonus=-14
        dp=2.4
        pp=0.0
    elif stat==8:
        skill_bonus=-13
        dp=2.6
        pp=0.0
    elif stat==9:
        skill_bonus=-12
        dp=2.7
        pp=0.0
    elif stat==10:
        skill_bonus=-11
        dp=2.8
        pp=0.0
    elif stat==11:
        skill_bonus=-10
        dp=2.9
        pp=0.0
    elif 12<=stat<=15:
        skill_bonus=-9
        dp=3.0
        pp=0.0
    elif 16<=stat<=18:
        skill_bonus=-8
        dp=3.3
        pp=0.0
    elif 19<=stat<=21:
        skill_bonus=-7
        dp=3.6
        pp=0.0
    elif 22<=stat<=24:
        skill_bonus=-6
        dp=3.8
        pp=0.0
    elif 25<=stat<=27:
        skill_bonus=-5
        dp=4.0
        pp=0.0
    elif 28<=stat<=30:
        skill_bonus=-4
        dp=4.3
        pp=0.0
    elif 31<=stat<=32:
        skill_bonus=-3
        dp=4.6
        pp=0.0
    elif 33<=stat<=36:
        skill_bonus=-2
        dp=4.8
        pp=0.0
    elif 37<=stat<=40:
        skill_bonus=-1
        dp=5.0
        pp=0.0
    elif 41<=stat<=59:
        skill_bonus=0
        dp=5.5
        pp=0.0
    elif 60<=stat<=63:
        skill_bonus=1
        dp=6.0
        pp=0.2
    elif 64<=stat<=67:
        skill_bonus=2
        dp=6.3
        pp=0.4
    elif 68<=stat<=71:
        skill_bonus=3
        dp=6.6
        pp=0.6
    elif 72<=stat<=74:
        skill_bonus=4
        dp=6.8
        pp=0.8
    elif 75<=stat<=77:
        skill_bonus=5
        dp=7.0
        pp=1.0
    elif 78<=stat<=80:
        skill_bonus=6
        dp=7.4
        pp=1.1
        print "num:",78
    elif 81<=stat<=83:
        skill_bonus=7
        dp=7.7
        pp=1.2
    elif 84<=stat<=86:
        skill_bonus=8
        dp=8.0
        pp=1.3
    elif 87<=stat<=89:
        skill_bonus=9
        dp=8.2
        pp=1.4
    elif stat==90:
        skill_bonus=10
        dp=8.4
        pp=1.5
    elif stat==91:
        skill_bonus=11
        dp=8.6
        pp=1.6
    elif stat==92:
        skill_bonus=12
        dp=8.7
        pp=1.7
    elif stat==93:
        skill_bonus=13
        dp=8.8
        pp=1.8
    elif stat==94:
        skill_bonus=14
        dp=8.9
        pp=1.9
    elif stat==95:
        skill_bonus=15
        dp=9.0
        pp=2.0
    elif stat==96:
        skill_bonus=17
        dp=9.2
        pp=2.2
    elif stat==97:
        skill_bonus=19
        dp=9.4
        pp=2.4
    elif stat==98:
        skill_bonus=21
        dp=9.6
        pp=2.6
    elif stat==99:
        skill_bonus=23
        dp=9.8
        pp=2.8
    elif stat==100:
        skill_bonus=25
        dp=10.0
        pp=3.0
    elif stat==101:
        skill_bonus=30
    #skill_bonus = (stat-50)/2
    #print "skill Bonus:",skill_bonus
    return (skill_bonus,dp,pp)

st_cur=78
skill_lookup(st_cur)
# Out:
# stat: 78
# num: 78
# (6, 7.4, 1.1)

# %%
# Out:
# stat: 78
# num: 78
# (6, 7.4, 1.1)
