# %%
mb=""
setstmb,setqumb,setprmb,setinmb,setemmb=0,0,0,0,0
setcomb,setagmb,setsdmb,setmemb,setremb=0,0,0,0,0
def mbset():
    global mb
    mb=int(raw_input("Bonus: "))
    return mb

mbloop=True
while mbloop:
    print 45 * "-"
    print "| 1.) Strength         6.) Constitution     |"
    print "| 2.) Quickness        7.) Agility          |"
    print "| 3.) Presence         8.) Self Discipline  |"
    print "| 4.) Intuition        9.) Memory           |"
    print "| 5.) Empathy         10.) Reasoning        |"
    print "|                                           |"
    print "| X.) Exit                                  |"
    print 45 * "-"
    print
    mbch=raw_input('Select Stat to add a bonus: ')
    if mbch == "1":
        mbset()
        setstmb=mb
        print setstmb,":mb"
    if mbch == "2":
        mbset()
        setqumb=mb
        print mb,":mb2"
    if mbch == "3":
        mbset()
        setprmb=mb
    if mbch == "4":
        mbset()
        setinmb=mb
    if mbch == "5":
        mbset()
        setemmb=mb
    if mbch == "6":
        mbset()
        setcomb=mb
    if mbch == "7":
        mbset()
        setagmb=mb
    if mbch == "8":
        mbset()
        setsdmb=mb
    if mbch == "9":
        mbset()
        setmemb=mb
    if mbch == "10":
        mbset()
        setremb=mb
    if mbch.upper() == "X":
        print "Exiting.."
        mbloop=False
        
print setstmb,":st"
print setqumb,":qu"
print setprmb,":pr"
# Out:
# ---------------------------------------------
# | 1.) Strength         6.) Constitution     |
# | 2.) Quickness        7.) Agility          |
# | 3.) Presence         8.) Self Discipline  |
# | 4.) Intuition        9.) Memory           |
# | 5.) Empathy         10.) Reasoning        |
# |                                           |
# | X.) Exit                                  |
# ---------------------------------------------
#
# Select Stat to add a bonus: 1
# Bonus: 5
# 5 :mb
# ---------------------------------------------
# | 1.) Strength         6.) Constitution     |
# | 2.) Quickness        7.) Agility          |
# | 3.) Presence         8.) Self Discipline  |
# | 4.) Intuition        9.) Memory           |
# | 5.) Empathy         10.) Reasoning        |
# |                                           |
# | X.) Exit                                  |
# ---------------------------------------------
#
# Select Stat to add a bonus: x
# Exiting..
# 5 :st
# 0 :qu
# 0 :pr
